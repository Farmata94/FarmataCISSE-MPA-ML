# %% [markdown]
#  # MKA-MLF, Lab_07 Convolutional Neural Networks

# %% [markdown]
# ## Exercise - XOR Gate

# %% [markdown]
# ## Exercise - Hand-written digits recognition

# %% [markdown]
# Create CNN which will process and recognize handwritten digits. For this purposes please use the MNIST database (Modified National Institute of Standards and Technology database) which is a large database of handwritten digits that is commonly used for training various image processing systems.
#
# The datasample of the MNIST datasets can be see in the following picture

# %% [markdown]
# ![mnist_data_sample.png](attachment:eb3e0d6a-ccb0-499d-9847-ecbc554dbce0.png)

# %% [markdown]
# ### Task description

# %% [markdown]
# In the terms of machine learning, the Hand-written digits recognition can be threated as a multi-class classification problem. This is very important knowledge to structure our model in the correct way (Especially the output-layer, including the number of neurons and activations function and the overall loss function and classification metrics)

# %% [markdown]
# ### 0. Import libraries

# %% [markdown]
# Import the all necessary libraries, you can get inspired by the previous exercises. You can improst the libraries gradually, when do you progressing with the task

# %%
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.datasets import mnist
import tensorflow as tf
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
###################################
# Write your own code here #



###################################
font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Dataset

# %% [markdown]
# #### 1.1 Load Dataset

# %% [markdown]
# You can load the dataset using the following code

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# #### 1.2 Dataset examination

# %% [markdown]
# Using the following code, display random images,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels = y_data[selected_ind]
  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img, cmap="gray")

  for id_label, label in enumerate(selected_labels):
    plt.text(14 + 28*id_label, 28*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %% [markdown]
# Examine the dataset. Answer for yourself the following questions:
#
# - What kind of data occurs in our dataset?
# - How many data samples do we have in train and test datasets?
# - How many colour channels does the input variable have?
# - What is the size of the input images?
# - What is the necessary preprocessing of the input data X?
# - How many classes do we have in target varoable?
# - What is the necessary preprocessing of target variable y?

# %% [markdown]
# #### 1.3 Dataset preprocessing

# %% [markdown]
# Perform the necessary data preprocessing. The best way to preprocess the data would be one hot encoding for the target variable and normalization for the input variable (using min-max or z-score normalization)

# %%
# Image normalization, set values between 0 and 1
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0


# One-Hot label encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Reshape
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %% [markdown]
# ### 2. Build the model

# %% [markdown]
# In this section, your task will be to define the model architecture. The intial structure can be defined as follows:
#
# Input_layer -> Convolutional_layer(kernel_size=(3,3), no_channels=32) -> Maxpooling_layer(kernel_size=(2, 2)) -> Flatten_layer -> Dense_layer (num_classes)

# %% [markdown]
# #### 2.1 Define the model structure

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)),  
    MaxPooling2D(pool_size=(2,2)),  
    Flatten(),  
    Dense(10, activation='softmax')  
])

# %% [markdown]
# #### 2.2 Compile the model

# %% [markdown]
# Build the model, use the relevant metrics, optimizer and loss function. While choosing the metrics and loss function, consider fact that we are are trying to solve the multiclass classification problem

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 10)                54090
#
# =================================================================
# Total params: 54,410
# Trainable params: 54,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. Training stage

# %% [markdown]
# #### 3.1 Model training

# %% [markdown]
# train your model, define the relevant hyperparameters (no. epochs, batch_size), use 20p of the training data for validation

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 9s 12ms/step - loss: 0.1438 - accuracy: 0.9557 - val_loss: 0.0818 - val_accuracy: 0.9755
# Epoch 2/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0627 - accuracy: 0.9815 - val_loss: 0.0643 - val_accuracy: 0.9812
# Epoch 3/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0436 - accuracy: 0.9864 - val_loss: 0.0763 - val_accuracy: 0.9803
# Epoch 4/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0360 - accuracy: 0.9882 - val_loss: 0.0722 - val_accuracy: 0.9812
# Epoch 5/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.0834 - val_accuracy: 0.9805
# Epoch 6/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 0.1091 - val_accuracy: 0.9769
# Epoch 7/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.1003 - val_accuracy: 0.9797
# Epoch 8/20
# 750/750 [==============================] - 9s 11ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.1174 - val_accuracy: 0.9794
# Epoch 9/20
# 750/750 [==============================] - 9s 11ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 0.1280 - val_accuracy: 0.9790
# Epoch 10/20
# 750/750 [==============================] - 9s 11ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.1190 - val_accuracy: 0.9802
# Epoch 11/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.1750 - val_accuracy: 0.9735
# Epoch 12/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.1550 - val_accuracy: 0.9762
# Epoch 13/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.1625 - val_accuracy: 0.9775
# Epoch 14/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.1638 - val_accuracy: 0.9795
# Epoch 15/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.1712 - val_accuracy: 0.9799
# Epoch 16/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.1958 - val_accuracy: 0.9778
# Epoch 17/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.2127 - val_accuracy: 0.9783
# Epoch 18/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.2219 - val_accuracy: 0.9788
# Epoch 19/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.1990 - val_accuracy: 0.9785
# Epoch 20/20
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.2063 - val_accuracy: 0.9791

# %% [markdown]
# #### 3.1 Model Evaluation on validation data

# %% [markdown]
# Plot the development of the training and validation loss, and training and validation metrics.

# %%
plt.figure(figsize=(12,5))

#Train loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Evolution')
plt.legend()

# Train Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Evolution')
plt.legend()

plt.show()

# %% [markdown]
# ### 4. Model evaluation

# %% [markdown]
# Evaluate the model on the testing dataset using the relevant metrics. Use the confusion metrics as the one of the metrics.

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")


plt.figure()
plt.plot(history.history['loss'])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1788 - accuracy: 0.9812
# Test Accuracy: 0.9812

# %%
# prediction

from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = model.predict(X_test)  
y_pred_classes = np.argmax(y_pred, axis=1)  
y_true = np.argmax(y_test, axis=1)  


conf_matrix = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=range(10), yticklabels=range(10))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ### 5. Hyperparameter tunning and regularization techniques

# %% [markdown]
# When your code is ready and fully functional, try several changes in the hyperparameters and see how they influence the testing metrics. Try changes in the network structure. You can also try adding regularization techniques such as L1, L2, and Dropout. Based on the development of training and validation loss, try to identify overfitting and avoid it

# %%
from tensorflow.keras.regularizers import l2
# Define
model = Sequential([
    Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)),  
    MaxPooling2D(pool_size=(2,2)),  
    Flatten(),  
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),  # L2 regularization
    Dropout(0.5),  
    Dense(10, activation='softmax')  
])

# Compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy']
)

model.summary()

# Training
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)


plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Evolution')
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Evolution')
plt.legend()

plt.show()

# Model Evaluation
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")

plt.figure()
plt.plot(history.history['loss'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 5408)              0
#
#  dense_1 (Dense)             (None, 128)               692352
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 693,962
# Trainable params: 693,962
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 12s 15ms/step - loss: 0.7877 - accuracy: 0.8520 - val_loss: 0.4407 - val_accuracy: 0.9414
# Epoch 2/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.5084 - accuracy: 0.9083 - val_loss: 0.3774 - val_accuracy: 0.9482
# Epoch 3/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.4527 - accuracy: 0.9218 - val_loss: 0.3278 - val_accuracy: 0.9620
# Epoch 4/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.4199 - accuracy: 0.9284 - val_loss: 0.3151 - val_accuracy: 0.9620
# Epoch 5/20
# 750/750 [==============================] - 11s 14ms/step - loss: 0.3905 - accuracy: 0.9352 - val_loss: 0.2834 - val_accuracy: 0.9668
# Epoch 6/20
# 750/750 [==============================] - 10s 13ms/step - loss: 0.3736 - accuracy: 0.9373 - val_loss: 0.2711 - val_accuracy: 0.9708
# Epoch 7/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.3574 - accuracy: 0.9416 - val_loss: 0.2678 - val_accuracy: 0.9674
# Epoch 8/20
# 750/750 [==============================] - 11s 14ms/step - loss: 0.3443 - accuracy: 0.9440 - val_loss: 0.2581 - val_accuracy: 0.9725
# Epoch 9/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.3313 - accuracy: 0.9463 - val_loss: 0.2491 - val_accuracy: 0.9712
# Epoch 10/20
# 750/750 [==============================] - 11s 14ms/step - loss: 0.3238 - accuracy: 0.9471 - val_loss: 0.2457 - val_accuracy: 0.9736
# Epoch 11/20
# 750/750 [==============================] - 10s 13ms/step - loss: 0.3162 - accuracy: 0.9488 - val_loss: 0.2480 - val_accuracy: 0.9692
# Epoch 12/20
# 750/750 [==============================] - 10s 13ms/step - loss: 0.3139 - accuracy: 0.9480 - val_loss: 0.2410 - val_accuracy: 0.9731
# Epoch 13/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.3077 - accuracy: 0.9507 - val_loss: 0.2404 - val_accuracy: 0.9719
# Epoch 14/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.3064 - accuracy: 0.9502 - val_loss: 0.2332 - val_accuracy: 0.9731
# Epoch 15/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.3043 - accuracy: 0.9514 - val_loss: 0.2327 - val_accuracy: 0.9727
# Epoch 16/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.2961 - accuracy: 0.9532 - val_loss: 0.2368 - val_accuracy: 0.9709
# Epoch 17/20
# 750/750 [==============================] - 10s 14ms/step - loss: 0.2983 - accuracy: 0.9517 - val_loss: 0.2387 - val_accuracy: 0.9741
# Epoch 18/20
# 750/750 [==============================] - 10s 13ms/step - loss: 0.3002 - accuracy: 0.9523 - val_loss: 0.2279 - val_accuracy: 0.9733
# Epoch 19/20
# 750/750 [==============================] - 10s 13ms/step - loss: 0.2960 - accuracy: 0.9528 - val_loss: 0.2331 - val_accuracy: 0.9753
# Epoch 20/20
# 750/750 [==============================] - 10s 13ms/step - loss: 0.2965 - accuracy: 0.9529 - val_loss: 0.2312 - val_accuracy: 0.9761
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2265 - accuracy: 0.9755
# Test Accuracy: 0.9755
